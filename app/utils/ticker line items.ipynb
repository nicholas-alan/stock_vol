# %%
import get_statements
import pandas as pd
import yfinance as yf
import financial_line_items

# %%
porto = ['nvda', 'aapl', 'ionq', 'rgti', 'goog']

# %%
nvda_quarterly = get_statements.tickers_quarterly_statements('nvda')

# %%
type(nvda_quarterly)
# Out:
# dict

# %%
portfolio = get_statements.tickers_statements(porto)

# %%
line_ass = {x:portfolio[x]['balance_sheet'].loc['Total Assets'] for x in portfolio.keys()}

# %%
portfolio_quarterly = get_statements.tickers_quarterly_statements(porto)

# %%
portfolio_quart_income = get_statements.tickers_quarterly_income_statements(portfolio_quarterly)

# %%
portfolio_quarterly['AAPL']['quarterly_income_statement']
# Out:
#                                                         2024-12-31  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                            0.21
# Normalized EBITDA                                    45912000000.0
# Net Income From Continuing Operation Net Minori...   36330000000.0
# Reconciled Depreciation                               3080000000.0
# Reconciled Cost Of Revenue                           66025000000.0
# EBITDA                                               45912000000.0
# EBIT                                                 42832000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    36330000000.0
# Net Income From Continuing And Discontinued Ope...   36330000000.0
# ...

# %%
# Out:
# 'Total Assets'

# %%
for x in portfolio_bs.keys(): pd.DataFrame(portfolio_bs[x])

# %%
'quarterly_income_statement' == 'quarterly_income_statement'
# Out:
# True

# %%
line_ass
# Out:
# {'NVDA': 2024-01-31    65728000000.0
#  2023-01-31    41182000000.0
#  2022-01-31    44187000000.0
#  2021-01-31    28791000000.0
#  Name: Total Assets, dtype: object,
#  'AAPL': 2024-09-30    364980000000.0
#  2023-09-30    352583000000.0
#  2022-09-30    352755000000.0
#  2021-09-30    351002000000.0
#  2020-09-30               NaN
#  Name: Total Assets, dtype: object,
#  'IONQ': 2023-12-31    553580000.0
#  2022-12-31    597992000.0
#  2021-12-31    642028000.0
#  2020-12-31     60478000.0
#  Name: Total Assets, dtype: object,
#  'RGTI': 2023-12-31    159913000.0
#  2022-12-31    203442000.0
#  2021-01-31     49682089.0
#  Name: Total Assets, dtype: object,
#  'GOOG': 2024-12-31    450256000000.0
#  2023-12-31    402392000000.0
#  2022-12-31    365264000000.0
#  2021-12-31    359268000000.0
#  2020-12-31               NaN
#  Name: Total Assets, dtype: object}

# %%
def tickers_quarterly_income_statements(tickers_quarterly_statements):
    """Extract quarterly income statements from fetched data."""
    return {
    ticker:data['quarterly_income_statement'] 
    for ticker, data tickers_quarterly_statements.items()
}
# Out:
#   Cell In[42], line 5
#     for ticker, data tickers_quarterly_statements.items()
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
