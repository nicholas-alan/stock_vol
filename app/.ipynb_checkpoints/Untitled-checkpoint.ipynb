# %%
from utils.oop_financial_statements import TickerFinancials
from utils.plot_pink import plot_pink
from utils.plot_pink_bars import plot_pink_bars

# %%
aapl_data = TickerFinancials('aapl')

# %%
aapl_data.annual_balance_sheet.loc['Total Assets']
# Out:
# 2024-09-30    364980000000.0
# 2023-09-30    352583000000.0
# 2022-09-30    352755000000.0
# 2021-09-30    351002000000.0
# 2020-09-30               NaN
# Name: Total Assets, dtype: object

# %%
plot_pink_bars(aapl_data.annual_balance_sheet.loc['Total Debt'], title=f'{aapl_data.ticker_symbol} {aapl_data.annual_balance_sheet.loc['Total Debt'].name}')
